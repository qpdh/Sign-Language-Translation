# %% [markdown]
# # 손가락 숫자 이미지를 21개 점으로 데이터화

# %% [markdown]
# ## 1. import 부분

# %%
import cv2
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands

# %%
import os
import numpy as np
import pandas as pd

# %%
path_dir = './Sign-Language-Digits-Dataset-master/Sign-Language-Digits-Dataset-master/Dataset/'
# 0 ... 9 손가락 숫자
path_type = [i for i in range(10)]

# %%
IMAGE_FILES = list()

for t in path_type:
    # 불러오는 위치
    from_path = path_dir + str(t) + '/'

    # 파일 불러오기
    file_list = os.listdir(from_path)
    # 확장자가 jpg 인 모든 파일을 불러온다.
    IMAGE_FILES+=[from_path+ file for file in file_list if file.endswith('.JPG')]

# %% [markdown]
# ## 2. 이미지 불러와서 처리

# %%
# For static images:
# TODO 여기 안에 처리되는 데이터를, 배열로 저장해서 CSV 형태로 저장

landmarks_list = list(list())

# 0 ~ 20
# x, y, z
# 63
# 63 + target[0 ~ 9]

# 데이터가 0~9 까지 각각 200개씩
# 최댓값은 2000개


with mp_hands.Hands(
static_image_mode = True,
max_num_hands = 1,
min_detection_confidence=0.5) as hands:
    for idx, file in enumerate(IMAGE_FILES):
        
        idx_landmarks = []
        
        image = cv2.flip(cv2.imread(file),1)
        
        result = hands.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        
        print('Handedness : ',result.multi_handedness)
        
        
        if not result.multi_hand_landmarks:
            continue
        
        image_hegiht, image_width, _ =image.shape
        
        annotated_image = image.copy()
        for hand_landmarks in result.multi_hand_landmarks:
            #rint("#######",len(hand_landmarks.landmark))
            
            # x, y, z 데이터 삽입
            for  i in hand_landmarks.landmark:
                idx_landmarks.append(i.x)
                idx_landmarks.append(i.y)
                idx_landmarks.append(i.z)
            
#             print('hand_landmarks : ',hand_landmarks)
            
#             print(
#             f'Index finger tip coordinates : (',
#             f'{hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x*image_width}, '
#             f'{hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y*image_hegiht}) ')
            
            
            # 결과 값 삽입

            idx_landmarks.append(int(file[82]))
            
            landmarks_list.append(idx_landmarks)
# Out:
# Handedness :  [classification {
#   index: 1
#   score: 0.5722333788871765
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9954045414924622
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9410454630851746
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9716020226478577
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9931164979934692
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9872878789901733
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9854844212532043
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.7865077257156372
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9860157370567322
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9905991554260254
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 0
#   score: 0.9203547835350037
#   label: "Left"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9953701496124268
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9884054660797119
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9898111820220947
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9454639554023743
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9905549883842468
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.992326021194458
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9793448448181152
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9906967282295227
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9918296337127686
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9943687915802002
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9952189922332764
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9926477074623108
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.995481550693512
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 0
#   score: 0.7020845413208008
#   label: "Left"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.976340651512146
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9630627632141113
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.98298180103302
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9494313597679138
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 0
#   score: 0.869827151298523
#   label: "Left"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9931533336639404
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9907608032226562
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9949567317962646
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9941530227661133
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.8423426151275635
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9911378622055054
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.926236093044281
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9937666058540344
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9943085312843323
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.5484100580215454
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9769019484519958
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9466826915740967
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9672501683235168
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9919406771659851
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9229761958122253
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9875388145446777
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.824550986289978
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.7412663698196411
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9898152351379395
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9425406455993652
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9850541949272156
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.8891829252243042
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.8921604156494141
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9861270189285278
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9889373779296875
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.987637460231781
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9676907062530518
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9891213178634644
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9637272357940674
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9873958826065063
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.7669347524642944
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9681488275527954
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9517309665679932
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.8705572485923767
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.975866973400116
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 0
#   score: 0.6323473453521729
#   label: "Left"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9709826111793518
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9567570090293884
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.967496931552887
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9675484895706177
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9852675199508667
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9687613248825073
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9886759519577026
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.981206476688385
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9808838963508606
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9384205341339111
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9881068468093872
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9775908589363098
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9909286499023438
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9707998037338257
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9442034363746643
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9914547204971313
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9793830513954163
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9773039221763611
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9616425037384033
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9782882332801819
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9670807123184204
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9746165871620178
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.945205569267273
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9752448797225952
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9777305722236633
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9652212262153625
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9692713022232056
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9772841334342957
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9805120825767517
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9358078837394714
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.738964319229126
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9665394425392151
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9817756414413452
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.956267237663269
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9787856936454773
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9795902967453003
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9687473773956299
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9728683233261108
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9791222810745239
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9509249925613403
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9766181707382202
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9613921642303467
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9619622826576233
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9504369497299194
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9825090169906616
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9724863767623901
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9790980815887451
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9750692844390869
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9843152761459351
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.8299693465232849
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9885770082473755
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9701917171478271
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.97857266664505
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9607316255569458
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.950122058391571
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9769796133041382
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 0
#   score: 0.7454177141189575
#   label: "Left"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9743189215660095
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9902070760726929
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9765844941139221
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9789833426475525
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.97920161485672
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9770718216896057
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9567694664001465
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9770129323005676
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9738342761993408
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9640586376190186
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9703900218009949
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9772886037826538
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9804127216339111
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9631550908088684
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9610593318939209
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.7553842663764954
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9692699909210205
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9713318943977356
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9465099573135376
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9845516085624695
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9876587390899658
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9626932740211487
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9544200897216797
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9765430688858032
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.7964643239974976
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9702126383781433
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.983633279800415
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 0
#   score: 0.6071268320083618
#   label: "Left"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9740827083587646
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9659914374351501
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9678462743759155
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9631304144859314
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9540038108825684
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9831052422523499
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9851218461990356
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9756374955177307
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9534233212471008
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9821275472640991
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9745898842811584
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9794326424598694
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9489367604255676
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.986741304397583
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9826556444168091
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9752715229988098
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9819003939628601
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9814469814300537
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9498973488807678
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9787259697914124
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9835193157196045
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9604417681694031
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9722259640693665
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.97925865650177
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9874783754348755
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.792472243309021
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9921362996101379
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9483432173728943
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9834474325180054
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9838787913322449
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9720973372459412
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9788469672203064
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9852029085159302
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9818053841590881
#   label: "Right"
# }
# ]
# Handedness :  None
# 호출
# Handedness :  None
# 호출
# Handedness :  [classification {
#   index: 1
#   score: 0.9636608958244324
#   label: "Right"
# }
# ]
# Handedness :  [classification {
#   index: 1
#   score: 0.9863499999046326
#   label: "Right"
# }
# ]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22776/2086623174.py in <module>
#      53 for t in path_type:
#      54     for dimension in ['x','y','z']:
# ---> 55         df_columns.append(t+'_'+dimension)
#      56
#      57 print(df_columns)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
df_columns = []
for i in range(21):
    for dimension in ['x','y','z']:
        df_columns.append(str(i)+'_'+dimension)
    
print(df_columns)

df_columns.append('target')

# print(landmarks_list)
df = pd.DataFrame(landmarks_list,columns=df_columns)
df.columns
print(df)
# Out:
# ['0_x', '0_y', '0_z', '1_x', '1_y', '1_z', '2_x', '2_y', '2_z', '3_x', '3_y', '3_z', '4_x', '4_y', '4_z', '5_x', '5_y', '5_z', '6_x', '6_y', '6_z', '7_x', '7_y', '7_z', '8_x', '8_y', '8_z', '9_x', '9_y', '9_z', '10_x', '10_y', '10_z', '11_x', '11_y', '11_z', '12_x', '12_y', '12_z', '13_x', '13_y', '13_z', '14_x', '14_y', '14_z', '15_x', '15_y', '15_z', '16_x', '16_y', '16_z', '17_x', '17_y', '17_z', '18_x', '18_y', '18_z', '19_x', '19_y', '19_z', '20_x', '20_y', '20_z']
#            0_x       0_y  0_z       1_x       1_y       1_z       2_x  \
# 0     0.391284  0.578747  0.0  0.500118  0.563816  0.001754  0.551543
# 1     0.492428  0.723930  0.0  0.409600  0.577760  0.064449  0.388369
# 2     0.485409  0.775739  0.0  0.421539  0.638672  0.079117  0.424086
# 3     0.538207  0.847275  0.0  0.424146  0.681695  0.109469  0.392705
# 4     0.665852  0.749208  0.0  0.482986  0.618091  0.056065  0.394869
# ...        ...       ...  ...       ...       ...       ...       ...
# 1076  0.500571  0.848809  0.0  0.376538  0.811876 -0.082233  0.257183
# 1077  0.489248  0.838179  0.0  0.376193  0.812578 -0.081835  0.248503
# 1078  0.390151  0.763636  0.0  0.293696  0.726381 -0.060118  0.232365
# 1079  0.408066  0.855779  0.0  0.314734  0.791366 -0.074860  0.244352
# 1080  0.451319  0.833095  0.0  0.332177  0.771238 -0.059666  0.244854
#
#            2_y       2_z       3_x  ...      18_x      18_y      18_z  \
# 0     0.502363  0.013240  0.587105  ...  0.482077  0.232771  0.004347
# 1     0.445719  0.067051  0.370040  ...  0.548629  0.283748 -0.154397
# 2     0.511336  0.099877  0.422692  ...  0.530294  0.345207 -0.070457
# 3     0.523952  0.127030  0.368718  ...  0.515031  0.239265 -0.135996
# 4     0.482624  0.032160  0.307718  ...  0.455173  0.298619 -0.261083
# ...        ...       ...       ...  ...       ...       ...       ...
# 1076  0.742918 -0.134508  0.206435  ...  0.772067  0.461490 -0.214060
# 1077  0.730568 -0.136262  0.194626  ...  0.688999  0.439846 -0.178321
# 1078  0.614638 -0.088434  0.252200  ...  0.590701  0.416125 -0.107123
# 1079  0.656357 -0.120894  0.265410  ...  0.701790  0.526244 -0.137939
# 1080  0.630838 -0.088471  0.259395  ...  0.701979  0.429953 -0.113725
#
#           19_x      19_y      19_z      20_x      20_y      20_z  target
# 0     0.519600  0.289698  0.009900  0.523785  0.354275  0.021811       0
# 1     0.478980  0.253011 -0.131568  0.430722  0.269521 -0.112849       0
# 2     0.482269  0.276597 -0.051381  0.436832  0.247921 -0.038136       0
# 3     0.420555  0.206239 -0.097783  0.352658  0.238511 -0.073088       0
# 4     0.350520  0.331238 -0.228450  0.305706  0.390393 -0.198157       0
# ...        ...       ...       ...       ...       ...       ...     ...
# 1076  0.850089  0.397955 -0.242180  0.912390  0.342476 -0.257763       9
# 1077  0.732127  0.364150 -0.202795  0.763249  0.299564 -0.219505       9
# 1078  0.616401  0.348649 -0.128580  0.631009  0.286070 -0.141795       9
# 1079  0.748821  0.465648 -0.154497  0.781799  0.408584 -0.165022       9
# 1080  0.738292  0.351742 -0.135308  0.758829  0.284495 -0.149694       9
#
# [1081 rows x 64 columns]

# %% [markdown]
# ## CSV 파일로 내보내기

# %%
df
df.to_csv('output.csv')

# %% [markdown]
# ## 이미지를 그리는 부분

# %%
 # 이미지를 그리는 부분
        mp_drawing.draw_landmarks(
        annotated_image,
        hand_landmarks,
        mp_hands.HAND_CONNECTIONS,
        mp_drawing_styles.get_default_hand_landmarks_style(),
        mp_drawing_styles.get_default_hand_connections_style())

        cv2.imwrite(
        './annotated_image'+str(idx)+'.png',cv2.flip(annotated_image,1))
